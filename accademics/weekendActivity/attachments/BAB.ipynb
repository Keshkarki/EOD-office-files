# %% [markdown]
# ## Betting Against Beta
# 1. Read the Nifty component stock list
# 2. Read the price data of the stocks
# 3. Calculate the beta
# 3. Generate signals and calculate strategy returns
# 4. Generate the signal based on beta and ROE
# 5. Compute portfolio returns
# 6. Returns analysis

# %% [markdown]
# ## Read the Nifty stock list and details

# %%
import warnings
warnings.simplefilter("ignore")
import matplotlib.pyplot as plt
plt.style.use('seaborn-darkgrid')
# %matplotlib inline
import pandas as pd
import numpy as np
nifty_list = pd.read_csv('ind_nifty50list.csv')
nifty_list.head()
# Out:
#                                  Company Name                  Industry
# 0  Adani Ports and Special Economic Zone Ltd.                  SERVICES  \
# 1                         Ambuja Cements Ltd.  CEMENT & CEMENT PRODUCTS
# 2                           Asian Paints Ltd.            CONSUMER GOODS
# 3                       Aurobindo Pharma Ltd.                    Pharma
# 4                              Axis Bank Ltd.        FINANCIAL SERVICES
#
#        Symbol Series     ISIN Code   ROE
# 0  ADANIPORTS     EQ  INE742F01042  16.3
# 1   AMBUJACEM     EQ  INE742F01042  10.0
# 2  ASIANPAINT     EQ  INE021A01026  22.7
# 3  AUROPHARMA     EQ  INE021A01026  20.0
# 4    AXISBANK     EQ  INE238A01034   7.0

# %% [markdown]
# ## Read the price data of each of the 50 stocks stored in the CSV file

# %%
import pandas as pd
data = pd.read_csv('nifty_stocks_prices.csv',index_col=0)
data.index = pd.to_datetime(data.index)
data.head(3)
# Out:
#             ADANIPORTS   AMBUJACEM  ASIANPAINT  AUROPHARMA    AXISBANK
# Date
# 2013-01-01  132.593399  169.479050  415.994751   92.478630  258.464874  \
# 2013-01-02  133.218826  171.536652  411.188751   96.422546  263.045410
# 2013-01-03  133.074493  173.384293  413.516541   96.661560  263.633423
#
#              BAJAJ-AUTO  BAJFINANCE       BPCL  BHARTIARTL  INDUSTOWER  ...
# Date                                                                    ...
# 2013-01-01  1752.848145  128.242920  79.952904  281.509186  137.813385  ...  \
# 2013-01-02  1810.690308  126.833817  82.230553  280.591461  140.426773  ...
# 2013-01-03  1821.091064  130.248566  82.185669  286.665649  142.412949  ...
#
#             TATAMOTORS   TATASTEEL       TECHM        UPL   ULTRACEMCO
# Date
# 2013-01-01  309.819305  345.589233  201.998383  80.702103  1973.043945  \
# 2013-01-02  311.041992  345.549774  203.307281  80.275444  1985.187622
# 2013-01-03  311.139771  348.822723  203.664276  83.384048  1975.043457
#
#                   VEDL       WIPRO    YESBANK        ZEEL    ^NSEI
# Date
# 2013-01-01  128.538559  137.047791  87.243210  212.813019      NaN
# 2013-01-02  131.321625  135.960098  89.227676  220.245026  5993.25
# 2013-01-03  132.292480  137.358566  90.023285  220.292664  6009.50
#
# [3 rows x 51 columns]

# %% [markdown]
# ## Daily percentage change

# %%
# Calculate the percentage change for each stock
data_pct_change = data.pct_change().dropna()
data_pct_change.head(3)
# Out:
#             ADANIPORTS  AMBUJACEM  ASIANPAINT  AUROPHARMA  AXISBANK
# Date
# 2013-07-24   -0.007834  -0.026972    0.009107   -0.015372 -0.064597  \
# 2013-07-25    0.011672  -0.105649    0.018923    0.034692  0.001866
# 2013-07-26   -0.025450   0.041228   -0.000954    0.003353 -0.017521
#
#             BAJAJ-AUTO  BAJFINANCE      BPCL  BHARTIARTL  INDUSTOWER  ...
# Date                                                                  ...
# 2013-07-24    0.013313   -0.031850 -0.013324    0.022115   -0.007921  ...  \
# 2013-07-25    0.000025   -0.008034  0.006034   -0.000889   -0.007984  ...
# 2013-07-26    0.015136   -0.037540  0.000571    0.000297    0.006707  ...
#
#             TATAMOTORS  TATASTEEL     TECHM       UPL  ULTRACEMCO      VEDL
# Date
# 2013-07-24   -0.005020  -0.021313  0.024170 -0.011111    0.004266 -0.030436  \
# 2013-07-25    0.008745  -0.029399 -0.023144  0.010183   -0.033693 -0.023718
# 2013-07-26   -0.033178  -0.017725  0.032254 -0.017032    0.005825 -0.062522
#
#                WIPRO   YESBANK      ZEEL     ^NSEI
# Date
# 2013-07-24  0.021213 -0.126069  0.002461 -0.014364
# 2013-07-25 -0.041035 -0.025173  0.061579 -0.013855
# 2013-07-26  0.015149 -0.017661 -0.028329 -0.003606
#
# [3 rows x 51 columns]

# %% [markdown]
# ---
# ## Calculate Beta

# %%
import statsmodels.api as sm
def calc_beta(y,x):
    model = sm.OLS(y,x)
    results = model.fit()
    return results.params[0]

# %%
beta = pd.DataFrame(index=[0])
for ticker in data_pct_change.columns:
    beta[ticker] = calc_beta(data_pct_change.loc[:'2017',ticker],data_pct_change.loc[:'2017','^NSEI'])
beta = beta.T
beta.columns = ['beta']

bar_p = beta.plot.bar(figsize=(18,7))

plt.show()

# %% [markdown]
# ## Alpha 1: Beta < 0.7

# %%
beta.plot.bar(figsize=(18,7),color=np.where(beta<0.7,'g','r').T)
plt.axhline(0.7,linestyle="-.",color='blue')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 beta.plot.bar(figsize=(18,7),color=np.where(beta<0.7,'g','r').T)
#       2 plt.axhline(0.7,linestyle="-.",color='blue')
#       3 plt.show()
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_core.py:1136, in PlotAccessor.bar(self, x, y, **kwargs)
#    1046 @Appender(
#    1047     """
#    1048     See Also
#    (...)
#    1125     self, x=None, y=None, **kwargs
#    1126 ) -> PlotAccessor:
#    1127     """
#    1128     Vertical bar plot.
#    1129
#    (...)
#    1134     other axis represents a measured value.
#    1135     """
# -> 1136     return self(kind="bar", x=x, y=y, **kwargs)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_core.py:975, in PlotAccessor.__call__(self, *args, **kwargs)
#     972             label_name = label_kw or data.columns
#     973             data.columns = label_name
# --> 975 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_matplotlib\core.py:448, in MPLPlot.generate(self)
#     446 self._compute_plot_data()
#     447 self._setup_subplots()
# --> 448 self._make_plot()
#     449 self._add_table()
#     450 self._make_legend()
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_matplotlib\core.py:1669, in BarPlot._make_plot(self)
#    1668 def _make_plot(self) -> None:
# -> 1669     colors = self._get_colors()
#    1670     ncolors = len(colors)
#    1672     pos_prior = neg_prior = np.zeros(len(self.data))
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_matplotlib\core.py:995, in MPLPlot._get_colors(self, num_colors, color_kwds)
#     992 if num_colors is None:
#     993     num_colors = self.nseries
# --> 995 return get_standard_colors(
#     996     num_colors=num_colors,
#     997     colormap=self.colormap,
#     998     color=self.kwds.get(color_kwds),
#     999 )
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_matplotlib\style.py:68, in get_standard_colors(num_colors, colormap, color_type, color)
#      65 if isinstance(color, dict):
#      66     return color
# ---> 68 colors = _derive_colors(
#      69     color=color,
#      70     colormap=colormap,
#      71     color_type=color_type,
#      72     num_colors=num_colors,
#      73 )
#      75 return list(_cycle_colors(colors, num_colors=num_colors))
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_matplotlib\style.py:125, in _derive_colors(color, colormap, color_type, num_colors)
#     120     if colormap is not None:
#     121         warnings.warn(
#     122             "'color' and 'colormap' cannot be used simultaneously. Using 'color'",
#     123             stacklevel=find_stack_level(),
#     124         )
# --> 125     return _get_colors_from_color(color)
#     126 else:
#     127     return _get_colors_from_color_type(color_type, num_colors=num_colors)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_matplotlib\style.py:171, in _get_colors_from_color(color)
#     168     return [color]
#     170 color = cast(Collection[Color], color)
# --> 171 return list(_gen_list_of_colors_from_iterable(color))
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_matplotlib\style.py:204, in _gen_list_of_colors_from_iterable(color)
#     202     yield x
#     203 else:
# --> 204     raise ValueError(f"Invalid color {x}")
#
# ValueError: Invalid color ['r' 'r' 'r' 'r' 'r' 'r' 'r' 'r' 'r' 'g' 'r' 'r' 'r' 'g' 'r' 'r' 'g' 'r'
#  'r' 'r' 'r' 'g' 'g' 'r' 'r' 'r' 'r' 'r' 'g' 'r' 'g' 'r' 'r' 'r' 'r' 'r'
#  'g' 'r' 'r' 'r' 'g' 'r' 'r' 'g' 'r' 'r' 'r' 'g' 'r' 'r' 'r']

# %%
low_beta = beta[beta.values < 0.7].index
low_beta
# Out:
# Index(['INDUSTOWER', 'DRREDDY', 'HCLTECH', 'HINDUNILVR', 'HDFC', 'INFY',
#        'LUPIN', 'POWERGRID', 'TCS', 'TECHM', 'WIPRO'],
#       dtype='object')

# %%
def plot_performance(stock_list, strategy_name):
    stk_returns = data_pct_change.loc['2018':, stock_list]
    (stk_returns+1).cumprod().plot(figsize=(15,7),legend="left")
    plt.title(strategy_name)
    plt.show()

    nifty = data_pct_change.loc['2018':, '^NSEI']
    portfolio = stk_returns.mean(axis=1)
    plt.title(strategy_name + ' Portfolio Performance')
    (portfolio+1).cumprod().plot(figsize=(15,7),label=strategy_name, color='purple')
    (nifty+1).cumprod().plot(figsize=(15,7),label='Nifty', color='blue')
    plt.legend()
    plt.show()
    return portfolio

# %%
p = plot_performance(low_beta, 'Low Beta')

# %% [markdown]
# ---
# ## Alpha 2: ROE > 18

# %%
high_roe = nifty_list[nifty_list.ROE>18].Symbol.values
high_roe
# Out:
# array(['ASIANPAINT', 'AUROPHARMA', 'BAJAJ-AUTO', 'BAJFINANCE', 'BPCL',
#        'COALINDIA', 'EICHERMOT', 'HCLTECH', 'HEROMOTOCO', 'HINDPETRO',
#        'HINDUNILVR', 'IBULHSGFIN', 'ITC', 'INFY', 'TCS', 'TECHM'],
#       dtype=object)

# %%
filtered_stocks = low_beta & high_roe
filtered_stocks
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 filtered_stocks = low_beta & high_roe
#       2 filtered_stocks
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\ops\common.py:81, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      77             return NotImplemented
#      79 other = item_from_zerodim(other)
# ---> 81 return method(self, other)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\arraylike.py:70, in OpsMixin.__and__(self, other)
#      68 @unpack_zerodim_and_defer("__and__")
#      69 def __and__(self, other):
# ---> 70     return self._logical_method(other, operator.and_)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:6791, in Index._logical_method(self, other, op)
#    6788 lvalues = self._values
#    6789 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 6791 res_values = ops.logical_op(lvalues, rvalues, op)
#    6792 return self._construct_result(res_values, name=res_name)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\ops\array_ops.py:394, in logical_op(left, right, op)
#     390 # For int vs int `^`, `|`, `&` are bitwise operators and return
#     391 #   integer dtypes.  Otherwise these are boolean ops
#     392 filler = fill_int if is_self_int_dtype and is_other_int_dtype else fill_bool
# --> 394 res_values = na_logical_op(lvalues, rvalues, op)
#     395 # error: Cannot call function of unknown type
#     396 res_values = filler(res_values)  # type: ignore[operator]
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\ops\array_ops.py:304, in na_logical_op(x, y, op)
#     294 def na_logical_op(x: np.ndarray, y, op):
#     295     try:
#     296         # For exposition, write:
#     297         #  yarr = isinstance(y, np.ndarray)
#    (...)
#     302         # Then Cases where this goes through without raising include:
#     303         #  (xint or xbool) and (yint or bool)
# --> 304         result = op(x, y)
#     305     except TypeError:
#     306         if isinstance(y, np.ndarray):
#     307             # bool-bool dtype operations should be OK, should not get here
#
# ValueError: operands could not be broadcast together with shapes (11,) (16,)

# %%
portfolio = plot_performance(filtered_stocks, 'Low Beta & High ROE')

# %% [markdown]
# <div class="alert alert-block alert-danger">
#     <b>Pro Tip</b>: Don't try to over optimize the beta and ROE threshold as it will lead to overfitting and reduce the predictive value of your strategy.
# </div>

# %% [markdown]
# ---
# ## Detailed Performance Analysis

# %%
import pyfolio as pf
pf.create_simple_tear_sheet(portfolio,benchmark_rets=data_pct_change.loc['2018':, '^NSEI'])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 import pyfolio as pf
#       2 pf.create_simple_tear_sheet(portfolio,benchmark_rets=data_pct_change.loc['2018':, '^NSEI'])
#
# ModuleNotFoundError: No module named 'pyfolio'

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2> Further Improvements </h2><BR>
#     1. Rebalance the portfolio on monthly or quarterly basis.<BR>
#     2. Backtest the strategy on different markets such as US equities, local equities, bond markets.<BR>
#     3. Add more fundamental factors such as ROCE, Debt to Equity to include good quality stocks in your portfolio.

# %% [markdown]
# ## References
# 1. [Betting Against Beta](https://www.sciencedirect.com/science/article/pii/S0304405X13002675)
# 2. [Quality Minus Junk](https://link.springer.com/article/10.1007/s11142-018-9470-2)
# 2. Nifty50 Historical Constituents Data: [Market cap and Weightage Report](https://www1.nseindia.com/products/content/equities/indices/archieve_indices.htm)
# 3. Screener.in
# <BR><BR>

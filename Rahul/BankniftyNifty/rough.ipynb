# %%
import pandas as pd

# Create a sample DataFrame
df = pd.DataFrame({
    'Name': ['John', 'Alice', 'Michael'],
    'Age': [25, 30, 35],
    'City': ['New York', 'London', 'Sydney']
})
df
# Out:
#       Name  Age      City
# 0     John   25  New York
# 1    Alice   30    London
# 2  Michael   35    Sydney

# %%
# Iterate over the rows of the DataFrame using iterrows
for index, row in df.iterrows():
    name = row['Name']
    age = row['Age']
    city = row['City']
    
    # Perform operations or print the row data
    print(f"Index: {index}, Name: {name}, Age: {age}, City: {city}")
# Out:
# Index: 0, Name: John, Age: 25, City: New York
# Index: 1, Name: Alice, Age: 30, City: London
# Index: 2, Name: Michael, Age: 35, City: Sydney

# %%
#variables
entryDaysFromExpiry = 0
exitDaysFromExpiry = 0
entryTime = '15:15'
exitTime = '15:15'
strikeDiff = 250                 
underlyingStrikeDiff = 50              

underlying = 'BANKNIFTY'
underlying_strike_diff = 100 if underlying == 'BANKNIFTY' else 50
OTM_points = 100

# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\kkark\\OneDrive\\Desktop\\OFFICE_FILES\\EOD-office-files\\Rahul\\BankniftyNifty\\Weekly_exp_dates.csv",usecols=['Exp_date'])


df['expDateDt'] = pd.to_datetime(df['Exp_date'],format='%d-%b-%y')

df['entry_date'] = df['expDateDt'] - pd.Timedelta(days=entryDaysFromExpiry)      #so we can have time delta
df['entry_date'] = df['entry_date'].astype('str')   #so we can concat time with it
df['entryDt'] = df['entry_date']+' '+entryTime
df['entryDt'] =  pd.to_datetime(df['entryDt'])
df['date'] = df['entryDt'].dt.date
df['time'] = df['entryDt'].dt.date
df.set_index('entryDt',inplace=True)
df = df[['expDateDt', 'date','time']]

# %%
df
# Out:
#                      expDateDt        date        time
# entryDt
# 2020-01-02 15:15:00 2020-01-02  2020-01-02  2020-01-02
# 2020-01-09 15:15:00 2020-01-09  2020-01-09  2020-01-09
# 2020-01-16 15:15:00 2020-01-16  2020-01-16  2020-01-16
# 2020-01-23 15:15:00 2020-01-23  2020-01-23  2020-01-23
# 2020-01-30 15:15:00 2020-01-30  2020-01-30  2020-01-30
# ...                        ...         ...         ...
# 2022-11-03 15:15:00 2022-11-03  2022-11-03  2022-11-03
# 2022-11-10 15:15:00 2022-11-10  2022-11-10  2022-11-10
# 2022-11-17 15:15:00 2022-11-17  2022-11-17  2022-11-17
# 2022-11-24 15:15:00 2022-11-24  2022-11-24  2022-11-24
# 2022-12-01 15:15:00 2022-12-01  2022-12-01  2022-12-01
#
# [153 rows x 3 columns]

# %%
a = df.index[0]
a
# Out:
# Timestamp('2020-01-02 15:15:00')

# %%
df.reset_index(inplace=True)

# %%
df.loc[df['entryDt']==a]
# Out:
#               entryDt  expDateDt        date        time
# 0 2020-01-02 15:15:00 2020-01-02  2020-01-02  2020-01-02

# %%
df.set_index('entryDt',inplace=True)

# %%
df
# Out:
#                      index  expDateDt        date        time
# entryDt
# 2020-01-02 15:15:00      0 2020-01-02  2020-01-02  2020-01-02
# 2020-01-09 15:15:00      1 2020-01-09  2020-01-09  2020-01-09
# 2020-01-16 15:15:00      2 2020-01-16  2020-01-16  2020-01-16
# 2020-01-23 15:15:00      3 2020-01-23  2020-01-23  2020-01-23
# 2020-01-30 15:15:00      4 2020-01-30  2020-01-30  2020-01-30
# ...                    ...        ...         ...         ...
# 2022-11-03 15:15:00    148 2022-11-03  2022-11-03  2022-11-03
# 2022-11-10 15:15:00    149 2022-11-10  2022-11-10  2022-11-10
# 2022-11-17 15:15:00    150 2022-11-17  2022-11-17  2022-11-17
# 2022-11-24 15:15:00    151 2022-11-24  2022-11-24  2022-11-24
# 2022-12-01 15:15:00    152 2022-12-01  2022-12-01  2022-12-01
#
# [153 rows x 4 columns]

# %%
df.loc[a,'index']
# Out:
# 0

# %%
a = df['entryDt'][0]
a
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\kkark\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File c:\Users\kkark\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\kkark\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'entryDt'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 a = df['entryDt'][0]
#       2 a
#
# File c:\Users\kkark\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File c:\Users\kkark\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 'entryDt'

# %%
df.loc[df['entryDt']==a,'time'] = 50

# %%
df
# Out:
#                 entryDt  expDateDt        date        time
# 0   2020-01-02 15:15:00 2020-01-02  2020-01-02          50
# 1   2020-01-09 15:15:00 2020-01-09  2020-01-09  2020-01-09
# 2   2020-01-16 15:15:00 2020-01-16  2020-01-16  2020-01-16
# 3   2020-01-23 15:15:00 2020-01-23  2020-01-23  2020-01-23
# 4   2020-01-30 15:15:00 2020-01-30  2020-01-30  2020-01-30
# ..                  ...        ...         ...         ...
# 148 2022-11-03 15:15:00 2022-11-03  2022-11-03  2022-11-03
# 149 2022-11-10 15:15:00 2022-11-10  2022-11-10  2022-11-10
# 150 2022-11-17 15:15:00 2022-11-17  2022-11-17  2022-11-17
# 151 2022-11-24 15:15:00 2022-11-24  2022-11-24  2022-11-24
# 152 2022-12-01 15:15:00 2022-12-01  2022-12-01  2022-12-01
#
# [153 rows x 4 columns]

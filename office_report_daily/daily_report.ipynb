# %% [markdown]
# Installing libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# reading file

# %%
df = pd.read_csv('4May23_orders.csv')
df
# Out:
#      SNo  Portfolio Name  Leg ID Exchange             Exchange Symbol Product
# 0      1  NF_CSL_STRANGS    1355      NFO      NIFTY 04MAY23 18150 CE     MIS  \
# 1      2  NF_CSL_STRANGS    1355      NFO      NIFTY 04MAY23 18150 CE     MIS
# 2      3  NF_CSL_STRANGS    1355      NFO      NIFTY 04MAY23 18150 CE     MIS
# 3      4  NF_CSL_STRANGS    1356      NFO      NIFTY 04MAY23 18050 PE     MIS
# 4      5  NF_CSL_STRANGS    1356      NFO      NIFTY 04MAY23 18050 PE     MIS
# ..   ...             ...     ...      ...                         ...     ...
# 211  212   BNF_25PCT_2RE    1372      NFO  BANKNIFTY 04MAY23 43300 PE     MIS
# 212  213   BNF_25PCT_2RE    1372      NFO  BANKNIFTY 04MAY23 43300 PE     MIS
# 213  214    NF_25PCT_2RE    1374      NFO      NIFTY 04MAY23 18100 PE     MIS
# 214  215    NF_25PCT_2RE    1374      NFO      NIFTY 04MAY23 18100 PE     MIS
# 215  216    NF_25PCT_2RE    1374      NFO      NIFTY 04MAY23 18100 PE     MIS
#
#     Order Type      Order ID                  Time   Txn  ...  Filled Qty
# 0       MARKET  2.020000e+11  04-May-2023 09.18.11  SELL  ...         150  \
# 1       MARKET  2.310000e+14  04-May-2023 09.18.11  SELL  ...         150
# 2       MARKET  1.100041e+09  04-May-2023 09.18.11  SELL  ...         150
# 3       MARKET  2.310000e+14  04-May-2023 09.18.11  SELL  ...         150
# 4       MARKET  1.100041e+09  04-May-2023 09.18.11  SELL  ...         150
# ..         ...           ...                   ...   ...  ...         ...
# 211     MARKET  2.020000e+11  04-May-2023 15.09.22   BUY  ...          75
# 212     MARKET  2.310000e+14  04-May-2023 15.09.22   BUY  ...          75
# 213     MARKET  2.310000e+14  04-May-2023 15.09.25   BUY  ...         150
# 214     MARKET  1.100299e+09  04-May-2023 15.09.25   BUY  ...         150
# 215     MARKET  2.020000e+11  04-May-2023 15.09.25   BUY  ...         150
#
#                Exchg Time Avg Price    Status Limit Price  Order Failed
# 0    04-May-2023 09.18.11     15.90  COMPLETE           0         False  \
# 1    01-Jan-0001 00.00.00     15.65  COMPLETE           0         False
# 2    01-Jan-0001 00.00.00     15.53  COMPLETE           0         False
# 3    01-Jan-0001 00.00.00     17.90  COMPLETE           0         False
# 4    01-Jan-0001 00.00.00     17.90  COMPLETE           0         False
# ..                    ...       ...       ...         ...           ...
# 211  04-May-2023 15.09.22      0.35  COMPLETE           0         False
# 212  01-Jan-0001 00.00.00      0.35  COMPLETE           0         False
# 213  01-Jan-0001 00.00.00      0.15  COMPLETE           0         False
# 214  01-Jan-0001 00.00.00      0.15  COMPLETE           0         False
# 215  04-May-2023 15.09.25      0.15  COMPLETE           0         False
#
#       User ID  User Alias Remarks       Tag
# 0        SIM1  SIMULATED1     NaN  10002264
# 1    50062865      RKEDEL     NaN  10002265
# 2    ASDE1950    AD1_IIFL     NaN  10002266
# 3    50062865      RKEDEL     NaN  10002269
# 4    ASDE1950    AD1_IIFL     NaN  10002270
# ..        ...         ...     ...       ...
# 211      SIM1  SIMULATED1     NaN  10002689
# 212  50062865      RKEDEL     NaN  10002690
# 213  50062865      RKEDEL     NaN  10002695
# 214  ASDE1950    AD1_IIFL     NaN  10002696
# 215      SIM1  SIMULATED1     NaN  10002697
#
# [216 rows x 21 columns]

# %%
df.shape
# Out:
# (216, 21)

# %%
df.insert(5,'Symbol',df['Exchange Symbol'].str.split().str.get(0))

# %%
df.columns
# Out:
# Index(['SNo', 'Portfolio Name', 'Leg ID', 'Exchange', 'Exchange Symbol',
#        'Symbol', 'Product', 'Order Type', 'Order ID', 'Time', 'Txn', 'Qty',
#        'Filled Qty', 'Exchg Time', 'Avg Price', 'Status', 'Limit Price',
#        'Order Failed', 'User ID', 'User Alias', 'Remarks', 'Tag'],
#       dtype='object')

# %% [markdown]
# ## importing lot sizes

# %%
from packages.underlaying import lot_size

# %%
df.insert(11,'lot_size',df['Symbol'].apply(lot_size))

# %%
df.insert(13,'no_of_lots',(df['Qty']/df['lot_size']).astype(int))

# %% [markdown]
# ## importing brokerage

# %%
from packages.brokerage import brokerage

# %%
df.insert(14,'brokerage_per_lot',df['Symbol'].apply(brokerage))

# %%
df.insert(15,'brokerage_cost',df['no_of_lots']*df['brokerage_per_lot'])

# %% [markdown]
# ## importing additional cost

# %%
from packages.additionalCost import additional_cost

# %%
df.insert(16,'additional_cost',(df['Symbol'].apply(additional_cost)*df['brokerage_cost']).astype(int))

# %%
df.insert(17,'Total_cost',(df['brokerage_cost']+df['additional_cost']))

# %%
pd.set_option('Display.max_columns',None)

# %%
df
# Out:
#      SNo  Portfolio Name  Leg ID Exchange             Exchange Symbol
# 0      1  NF_CSL_STRANGS    1355      NFO      NIFTY 04MAY23 18150 CE  \
# 1      2  NF_CSL_STRANGS    1355      NFO      NIFTY 04MAY23 18150 CE
# 2      3  NF_CSL_STRANGS    1355      NFO      NIFTY 04MAY23 18150 CE
# 3      4  NF_CSL_STRANGS    1356      NFO      NIFTY 04MAY23 18050 PE
# 4      5  NF_CSL_STRANGS    1356      NFO      NIFTY 04MAY23 18050 PE
# ..   ...             ...     ...      ...                         ...
# 211  212   BNF_25PCT_2RE    1372      NFO  BANKNIFTY 04MAY23 43300 PE
# 212  213   BNF_25PCT_2RE    1372      NFO  BANKNIFTY 04MAY23 43300 PE
# 213  214    NF_25PCT_2RE    1374      NFO      NIFTY 04MAY23 18100 PE
# 214  215    NF_25PCT_2RE    1374      NFO      NIFTY 04MAY23 18100 PE
# 215  216    NF_25PCT_2RE    1374      NFO      NIFTY 04MAY23 18100 PE
#
#         Symbol Product Order Type      Order ID                  Time   Txn
# 0        NIFTY     MIS     MARKET  2.020000e+11  04-May-2023 09.18.11  SELL  \
# 1        NIFTY     MIS     MARKET  2.310000e+14  04-May-2023 09.18.11  SELL
# 2        NIFTY     MIS     MARKET  1.100041e+09  04-May-2023 09.18.11  SELL
# 3        NIFTY     MIS     MARKET  2.310000e+14  04-May-2023 09.18.11  SELL
# 4        NIFTY     MIS     MARKET  1.100041e+09  04-May-2023 09.18.11  SELL
# ..         ...     ...        ...           ...                   ...   ...
# 211  BANKNIFTY     MIS     MARKET  2.020000e+11  04-May-2023 15.09.22   BUY
# 212  BANKNIFTY     MIS     MARKET  2.310000e+14  04-May-2023 15.09.22   BUY
# 213      NIFTY     MIS     MARKET  2.310000e+14  04-May-2023 15.09.25   BUY
# 214      NIFTY     MIS     MARKET  1.100299e+09  04-May-2023 15.09.25   BUY
# 215      NIFTY     MIS     MARKET  2.020000e+11  04-May-2023 15.09.25   BUY
#
#      lot_size  Qty  no_of_lots  brokerage_per_lot  brokerage_cost
# 0          50  150           3                  5              15  \
# 1          50  150           3                  5              15
# 2          50  150           3                  5              15
# 3          50  150           3                  5              15
# 4          50  150           3                  5              15
# ..        ...  ...         ...                ...             ...
# 211        25   75           3                  5              15
# 212        25   75           3                  5              15
# 213        50  150           3                  5              15
# 214        50  150           3                  5              15
# 215        50  150           3                  5              15
#
#      additional_cost  Total_cost  Filled Qty            Exchg Time  Avg Price
# 0                  3          18         150  04-May-2023 09.18.11      15.90  \
# 1                  3          18         150  01-Jan-0001 00.00.00      15.65
# 2                  3          18         150  01-Jan-0001 00.00.00      15.53
# 3                  3          18         150  01-Jan-0001 00.00.00      17.90
# 4                  3          18         150  01-Jan-0001 00.00.00      17.90
# ..               ...         ...         ...                   ...        ...
# 211                3          18          75  04-May-2023 15.09.22       0.35
# 212                3          18          75  01-Jan-0001 00.00.00       0.35
# 213                3          18         150  01-Jan-0001 00.00.00       0.15
# 214                3          18         150  01-Jan-0001 00.00.00       0.15
# 215                3          18         150  04-May-2023 15.09.25       0.15
#
#        Status  Limit Price  Order Failed   User ID  User Alias Remarks
# 0    COMPLETE            0         False      SIM1  SIMULATED1     NaN  \
# 1    COMPLETE            0         False  50062865      RKEDEL     NaN
# 2    COMPLETE            0         False  ASDE1950    AD1_IIFL     NaN
# 3    COMPLETE            0         False  50062865      RKEDEL     NaN
# 4    COMPLETE            0         False  ASDE1950    AD1_IIFL     NaN
# ..        ...          ...           ...       ...         ...     ...
# 211  COMPLETE            0         False      SIM1  SIMULATED1     NaN
# 212  COMPLETE            0         False  50062865      RKEDEL     NaN
# 213  COMPLETE            0         False  50062865      RKEDEL     NaN
# 214  COMPLETE            0         False  ASDE1950    AD1_IIFL     NaN
# 215  COMPLETE            0         False      SIM1  SIMULATED1     NaN
#
#           Tag
# 0    10002264
# 1    10002265
# 2    10002266
# 3    10002269
# 4    10002270
# ..        ...
# 211  10002689
# 212  10002690
# 213  10002695
# 214  10002696
# 215  10002697
#
# [216 rows x 28 columns]

# %%
def new_price(row):
    if row['Txn'] =='SELL':
        return (row['Avg Price']*row['Qty']-row['Total_cost'])/row['Qty']
    
    else:
        return (row['Avg Price']*row['Qty']+row['Total_cost'])/row['Qty']

# %%
df['New Price']= df.apply(new_price,axis=1)

# %%
df
# Out:
#      SNo  Portfolio Name  Leg ID Exchange             Exchange Symbol
# 0      1  NF_CSL_STRANGS    1355      NFO      NIFTY 04MAY23 18150 CE  \
# 1      2  NF_CSL_STRANGS    1355      NFO      NIFTY 04MAY23 18150 CE
# 2      3  NF_CSL_STRANGS    1355      NFO      NIFTY 04MAY23 18150 CE
# 3      4  NF_CSL_STRANGS    1356      NFO      NIFTY 04MAY23 18050 PE
# 4      5  NF_CSL_STRANGS    1356      NFO      NIFTY 04MAY23 18050 PE
# ..   ...             ...     ...      ...                         ...
# 211  212   BNF_25PCT_2RE    1372      NFO  BANKNIFTY 04MAY23 43300 PE
# 212  213   BNF_25PCT_2RE    1372      NFO  BANKNIFTY 04MAY23 43300 PE
# 213  214    NF_25PCT_2RE    1374      NFO      NIFTY 04MAY23 18100 PE
# 214  215    NF_25PCT_2RE    1374      NFO      NIFTY 04MAY23 18100 PE
# 215  216    NF_25PCT_2RE    1374      NFO      NIFTY 04MAY23 18100 PE
#
#         Symbol Product Order Type      Order ID                  Time   Txn
# 0        NIFTY     MIS     MARKET  2.020000e+11  04-May-2023 09.18.11  SELL  \
# 1        NIFTY     MIS     MARKET  2.310000e+14  04-May-2023 09.18.11  SELL
# 2        NIFTY     MIS     MARKET  1.100041e+09  04-May-2023 09.18.11  SELL
# 3        NIFTY     MIS     MARKET  2.310000e+14  04-May-2023 09.18.11  SELL
# 4        NIFTY     MIS     MARKET  1.100041e+09  04-May-2023 09.18.11  SELL
# ..         ...     ...        ...           ...                   ...   ...
# 211  BANKNIFTY     MIS     MARKET  2.020000e+11  04-May-2023 15.09.22   BUY
# 212  BANKNIFTY     MIS     MARKET  2.310000e+14  04-May-2023 15.09.22   BUY
# 213      NIFTY     MIS     MARKET  2.310000e+14  04-May-2023 15.09.25   BUY
# 214      NIFTY     MIS     MARKET  1.100299e+09  04-May-2023 15.09.25   BUY
# 215      NIFTY     MIS     MARKET  2.020000e+11  04-May-2023 15.09.25   BUY
#
#      lot_size  Qty  no_of_lots  brokerage_per_lot  brokerage_cost
# 0          50  150           3                  5              15  \
# 1          50  150           3                  5              15
# 2          50  150           3                  5              15
# 3          50  150           3                  5              15
# 4          50  150           3                  5              15
# ..        ...  ...         ...                ...             ...
# 211        25   75           3                  5              15
# 212        25   75           3                  5              15
# 213        50  150           3                  5              15
# 214        50  150           3                  5              15
# 215        50  150           3                  5              15
#
#      additional_cost  Total_cost  Filled Qty            Exchg Time  Avg Price
# 0                  3          18         150  04-May-2023 09.18.11      15.90  \
# 1                  3          18         150  01-Jan-0001 00.00.00      15.65
# 2                  3          18         150  01-Jan-0001 00.00.00      15.53
# 3                  3          18         150  01-Jan-0001 00.00.00      17.90
# 4                  3          18         150  01-Jan-0001 00.00.00      17.90
# ..               ...         ...         ...                   ...        ...
# 211                3          18          75  04-May-2023 15.09.22       0.35
# 212                3          18          75  01-Jan-0001 00.00.00       0.35
# 213                3          18         150  01-Jan-0001 00.00.00       0.15
# 214                3          18         150  01-Jan-0001 00.00.00       0.15
# 215                3          18         150  04-May-2023 15.09.25       0.15
#
#        Status  Limit Price  Order Failed   User ID  User Alias Remarks
# 0    COMPLETE            0         False      SIM1  SIMULATED1     NaN  \
# 1    COMPLETE            0         False  50062865      RKEDEL     NaN
# 2    COMPLETE            0         False  ASDE1950    AD1_IIFL     NaN
# 3    COMPLETE            0         False  50062865      RKEDEL     NaN
# 4    COMPLETE            0         False  ASDE1950    AD1_IIFL     NaN
# ..        ...          ...           ...       ...         ...     ...
# 211  COMPLETE            0         False      SIM1  SIMULATED1     NaN
# 212  COMPLETE            0         False  50062865      RKEDEL     NaN
# 213  COMPLETE            0         False  50062865      RKEDEL     NaN
# 214  COMPLETE            0         False  ASDE1950    AD1_IIFL     NaN
# 215  COMPLETE            0         False      SIM1  SIMULATED1     NaN
#
#           Tag  New Price
# 0    10002264      15.78
# 1    10002265      15.53
# 2    10002266      15.41
# 3    10002269      17.78
# 4    10002270      17.78
# ..        ...        ...
# 211  10002689       0.59
# 212  10002690       0.59
# 213  10002695       0.27
# 214  10002696       0.27
# 215  10002697       0.27
#
# [216 rows x 29 columns]

# %%
def new_amount(row):
    if row['Txn'] == 'SELL':
        return row['New Price']*row['Qty']
    
    else:
        return -(row['New Price']*row['Qty'])

# %%
df['New Amount']=df.apply(new_amount,axis=1)

# %%
df
# Out:
#      SNo  Portfolio Name  Leg ID Exchange             Exchange Symbol
# 0      1  NF_CSL_STRANGS    1355      NFO      NIFTY 04MAY23 18150 CE  \
# 1      2  NF_CSL_STRANGS    1355      NFO      NIFTY 04MAY23 18150 CE
# 2      3  NF_CSL_STRANGS    1355      NFO      NIFTY 04MAY23 18150 CE
# 3      4  NF_CSL_STRANGS    1356      NFO      NIFTY 04MAY23 18050 PE
# 4      5  NF_CSL_STRANGS    1356      NFO      NIFTY 04MAY23 18050 PE
# ..   ...             ...     ...      ...                         ...
# 211  212   BNF_25PCT_2RE    1372      NFO  BANKNIFTY 04MAY23 43300 PE
# 212  213   BNF_25PCT_2RE    1372      NFO  BANKNIFTY 04MAY23 43300 PE
# 213  214    NF_25PCT_2RE    1374      NFO      NIFTY 04MAY23 18100 PE
# 214  215    NF_25PCT_2RE    1374      NFO      NIFTY 04MAY23 18100 PE
# 215  216    NF_25PCT_2RE    1374      NFO      NIFTY 04MAY23 18100 PE
#
#         Symbol Product Order Type      Order ID                  Time   Txn
# 0        NIFTY     MIS     MARKET  2.020000e+11  04-May-2023 09.18.11  SELL  \
# 1        NIFTY     MIS     MARKET  2.310000e+14  04-May-2023 09.18.11  SELL
# 2        NIFTY     MIS     MARKET  1.100041e+09  04-May-2023 09.18.11  SELL
# 3        NIFTY     MIS     MARKET  2.310000e+14  04-May-2023 09.18.11  SELL
# 4        NIFTY     MIS     MARKET  1.100041e+09  04-May-2023 09.18.11  SELL
# ..         ...     ...        ...           ...                   ...   ...
# 211  BANKNIFTY     MIS     MARKET  2.020000e+11  04-May-2023 15.09.22   BUY
# 212  BANKNIFTY     MIS     MARKET  2.310000e+14  04-May-2023 15.09.22   BUY
# 213      NIFTY     MIS     MARKET  2.310000e+14  04-May-2023 15.09.25   BUY
# 214      NIFTY     MIS     MARKET  1.100299e+09  04-May-2023 15.09.25   BUY
# 215      NIFTY     MIS     MARKET  2.020000e+11  04-May-2023 15.09.25   BUY
#
#      lot_size  Qty  no_of_lots  brokerage_per_lot  brokerage_cost
# 0          50  150           3                  5              15  \
# 1          50  150           3                  5              15
# 2          50  150           3                  5              15
# 3          50  150           3                  5              15
# 4          50  150           3                  5              15
# ..        ...  ...         ...                ...             ...
# 211        25   75           3                  5              15
# 212        25   75           3                  5              15
# 213        50  150           3                  5              15
# 214        50  150           3                  5              15
# 215        50  150           3                  5              15
#
#      additional_cost  Total_cost  Filled Qty            Exchg Time  Avg Price
# 0                  3          18         150  04-May-2023 09.18.11      15.90  \
# 1                  3          18         150  01-Jan-0001 00.00.00      15.65
# 2                  3          18         150  01-Jan-0001 00.00.00      15.53
# 3                  3          18         150  01-Jan-0001 00.00.00      17.90
# 4                  3          18         150  01-Jan-0001 00.00.00      17.90
# ..               ...         ...         ...                   ...        ...
# 211                3          18          75  04-May-2023 15.09.22       0.35
# 212                3          18          75  01-Jan-0001 00.00.00       0.35
# 213                3          18         150  01-Jan-0001 00.00.00       0.15
# 214                3          18         150  01-Jan-0001 00.00.00       0.15
# 215                3          18         150  04-May-2023 15.09.25       0.15
#
#        Status  Limit Price  Order Failed   User ID  User Alias Remarks
# 0    COMPLETE            0         False      SIM1  SIMULATED1     NaN  \
# 1    COMPLETE            0         False  50062865      RKEDEL     NaN
# 2    COMPLETE            0         False  ASDE1950    AD1_IIFL     NaN
# 3    COMPLETE            0         False  50062865      RKEDEL     NaN
# 4    COMPLETE            0         False  ASDE1950    AD1_IIFL     NaN
# ..        ...          ...           ...       ...         ...     ...
# 211  COMPLETE            0         False      SIM1  SIMULATED1     NaN
# 212  COMPLETE            0         False  50062865      RKEDEL     NaN
# 213  COMPLETE            0         False  50062865      RKEDEL     NaN
# 214  COMPLETE            0         False  ASDE1950    AD1_IIFL     NaN
# 215  COMPLETE            0         False      SIM1  SIMULATED1     NaN
#
#           Tag  New Price  New Amount
# 0    10002264      15.78     2367.00
# 1    10002265      15.53     2329.50
# 2    10002266      15.41     2311.50
# 3    10002269      17.78     2667.00
# 4    10002270      17.78     2667.00
# ..        ...        ...         ...
# 211  10002689       0.59      -44.25
# 212  10002690       0.59      -44.25
# 213  10002695       0.27      -40.50
# 214  10002696       0.27      -40.50
# 215  10002697       0.27      -40.50
#
# [216 rows x 30 columns]

# %%
df.columns
# Out:
# Index(['SNo', 'Portfolio Name', 'Leg ID', 'Exchange', 'Exchange Symbol',
#        'Symbol', 'Product', 'Order Type', 'Order ID', 'Time', 'Txn',
#        'lot_size', 'Qty', 'no_of_lots', 'brokerage_per_lot', 'brokerage_cost',
#        'additional_cost', 'Total_cost', 'Filled Qty', 'Exchg Time',
#        'Avg Price', 'Status', 'Limit Price', 'Order Failed', 'User ID',
#        'User Alias', 'Remarks', 'Tag', 'New Price', 'New Amount'],
#       dtype='object')

# %%
df['Portfolio Name'].value_counts()
# Out:
# Portfolio Name
# NF_CSL_STRANGS          24
# BNF_CSL_STRANGS         24
# NF_CSL_STRANGS REX1     24
# NF_CSL_STRANGS REX2     24
# BNF_CSL_STRANGS REX1    24
# BNF_CSL_STRANGS REX2    24
# NF_70PCT                12
# BNF_70PCT               12
# BNF_CP_2RE              12
# NF_CP_2RE               12
# BNF_25PCT_2RE           12
# NF_25PCT_2RE            12
# Name: count, dtype: int64

# %% [markdown]
# ### extracted main portfolio names

# %%
df.insert(2,'P_names',df['Portfolio Name'].str.extract('(CSL_STRANGS|70PCT|CP_2RE|25PCT_2RE)'))

# %%
grp = df.groupby(['User Alias','P_names'])[['New Price','New Amount']].sum().reset_index()
grp
# Out:
#     User Alias      P_names  New Price  New Amount
# 0     AD1_IIFL    25PCT_2RE     510.35     8072.25
# 1     AD1_IIFL        70PCT     593.41     1493.25
# 2     AD1_IIFL       CP_2RE     634.76     3546.00
# 3     AD1_IIFL  CSL_STRANGS     723.72     5683.50
# 4       RKEDEL    25PCT_2RE     513.17     8277.00
# 5       RKEDEL        70PCT     593.04     1806.75
# 6       RKEDEL       CP_2RE     635.57     3486.75
# 7       RKEDEL  CSL_STRANGS     723.38     5347.50
# 8   SIMULATED1    25PCT_2RE     514.65     8556.00
# 9   SIMULATED1        70PCT     597.44     1410.75
# 10  SIMULATED1       CP_2RE     640.34     3663.00
# 11  SIMULATED1  CSL_STRANGS     728.03     5746.50

# %%
grp[grp['User Alias']=='AD1_IIFL']['New Amount'].sum()
# Out:
# 18795.000000000004

# %%
import numpy as np
import pandas as pd

# %%
df =  pd.read_excel('client_name_extractor.xlsx')
df
# Out:
#            client details         details  Unnamed: 2  Unnamed: 3  Unnamed: 4
# 0      Name of the client  SANGEETA SINGH         NaN         NaN         NaN  \
# 1    UCC(s) of the client        SANG0104         NaN         NaN         NaN
# 2       PAN of the client      AXOPS6228B         NaN         NaN         NaN
# 3                   Basis           Trade         NaN         NaN         NaN
# 4   Date of Issue of AGTS      16/06/2023         NaN         NaN         NaN
# 5          Financial Year       2023-2024         NaN         NaN         NaN
# 6                     NaN             NaN         NaN         NaN         NaN
# 7                     NaN             NaN         NaN         NaN         NaN
# 8                     NaN             NaN         NaN         NaN         NaN
# 9                     NaN             NaN         NaN         NaN         NaN
# 10                    NaN             NaN         NaN         NaN         NaN
#
# ...

# %%
df = df.iloc[:6,0:2]
df
# Out:
#           client details         details
# 0     Name of the client  SANGEETA SINGH
# 1   UCC(s) of the client        SANG0104
# 2      PAN of the client      AXOPS6228B
# 3                  Basis           Trade
# 4  Date of Issue of AGTS      16/06/2023
# 5         Financial Year       2023-2024

# %%
np.where(df['client details'] == 'Name of the client', df.loc[0,'details'], False)[0]
# Out:
# 'SANGEETA SINGH'
